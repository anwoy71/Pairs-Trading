# %%
import pandas_datareader as pdr
import yfinance as yf
print(yf.__version__)
# Out:
# 0.2.66

# %%
import yfinance as yf

df = yf.download(['','MSFT','BTC-USD'], start='2020-09-25', end='2020-10-02')

df
# Out:
# /tmp/ipykernel_118951/4006053133.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(['BSE','MSFT','BTC-USD'], start='2020-09-25', end='2020-10-02')
# [*********************100%***********************]  3 of 3 completed
#
# 1 Failed download:
# ['BSE']: YFTzMissingError('possibly delisted; no timezone found')
# Price      Adj Close Close                           High                \
# Ticker           BSE   BSE       BTC-USD        MSFT  BSE       BTC-USD
# Date
# 2020-09-25       NaN   NaN  10692.716797  199.263092  NaN  10777.696289
# 2020-09-26       NaN   NaN  10750.723633         NaN  NaN  10772.999023
# 2020-09-27       NaN   NaN  10775.269531         NaN  NaN  10803.976562
# 2020-09-28       NaN   NaN  10709.652344  200.816422  NaN  10945.347656
# 2020-09-29       NaN   NaN  10844.640625  198.726151  NaN  10860.000977
# 2020-09-30       NaN   NaN  10784.491211  201.669754  NaN  10847.256836
# ...
